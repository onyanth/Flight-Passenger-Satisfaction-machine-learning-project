# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Analysis/xccelerate/02MachineLearning/ML Project/Airline Passenger satisfaction.csv')

# %%
df.head(5)
# Out:
#        id satisfaction_v2  Gender   Customer Type  Age   Type of Travel  \
# 0   11112       satisfied  Female  Loyal Customer   65  Personal Travel
# 1  110278       satisfied    Male  Loyal Customer   47  Personal Travel
# 2  103199       satisfied  Female  Loyal Customer   15  Personal Travel
# 3   47462       satisfied  Female  Loyal Customer   60  Personal Travel
# 4  120011       satisfied  Female  Loyal Customer   70  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0       Eco              265             0                                  0
# 1  Business             2464             0                                  0
# 2       Eco             2138             0                                  0
# 3       Eco              623             0                                  0
# 4       Eco              354             0                                  0
#
#    ...  Online support  Ease of Online booking  On-board service  \
# 0  ...               2                       3                 3
# 1  ...               2                       3                 4
# 2  ...               2                       2                 3
# 3  ...               3                       1                 1
# 4  ...               4                       2                 2
#
#    Leg room service  Baggage handling  Checkin service  Cleanliness  \
# 0                 0                 3                5            3
# 1                 4                 4                2            3
# 2                 3                 4                4            4
# 3                 0                 1                4            1
# 4                 0                 2                4            2
#
#    Online boarding  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                2                           0                       0.0
# 1                2                         310                     305.0
# 2                2                           0                       0.0
# 3                3                           0                       0.0
# 4                5                           0                       0.0
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
len(df.id.unique())  #check if all IDs are unique and if the ID needs to be in trained set
# Out:
# 129880

# %%
df.satisfaction_v2.value_counts()
# Out:
# satisfied                  71087
# neutral or dissatisfied    58793
# Name: satisfaction_v2, dtype: int64

# %%
df.isna().sum()    #find out that there are 393 null values in the col. "Arrival Delay in Minutes"
# Out:
# id                                     0
# satisfaction_v2                        0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
temp = df[df["Arrival Delay in Minutes"].isna()]
temp.describe()     #compare the overall stat details of with the rows containing null-value in the col. "Arrival Delay in Minutes"
# Out:
#                   id         Age  Flight Distance  Seat comfort  \
# count     393.000000  393.000000       393.000000    393.000000
# mean    59064.106870   39.162850      2113.229008      2.842239
# std     38223.550326   15.707269      1094.182254      1.430551
# min       247.000000    7.000000        52.000000      0.000000
# 25%     25319.000000   27.000000      1376.000000      2.000000
# 50%     50960.000000   39.000000      2026.000000      3.000000
# 75%     96264.000000   51.000000      2690.000000      4.000000
# max    129489.000000   72.000000      5549.000000      5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                         393.000000      393.000000     393.000000
# mean                            3.111959        2.842239       3.005089
# std                             1.537851        1.491659       1.324793
# min                             0.000000        0.000000       1.000000
# 25%                             2.000000        2.000000       2.000000
# 50%                             3.000000        3.000000       3.000000
# 75%                             4.000000        4.000000       4.000000
# max                             5.000000        5.000000       5.000000
#
#        Inflight wifi service  Inflight entertainment  Online support  \
# count             393.000000              393.000000      393.000000
# mean                3.239186                3.295165        3.432570
# std                 1.337753                1.377443        1.365074
# min                 0.000000                0.000000        1.000000
# 25%                 2.000000                2.000000        2.000000
# 50%                 3.000000                4.000000        4.000000
# 75%                 4.000000                4.000000        5.000000
# max                 5.000000                5.000000        5.000000
#
#        Ease of Online booking  On-board service  Leg room service  \
# count              393.000000        393.000000        393.000000
# mean                 3.450382          3.442748          3.414758
# std                  1.302747          1.298510          1.339542
# min                  1.000000          1.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  5.000000          5.000000          5.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Cleanliness  Online boarding  \
# count        393.000000       393.000000   393.000000       393.000000
# mean           3.765903         3.366412     3.664122         3.366412
# std            1.154476         1.268975     1.181991         1.329835
# min            1.000000         1.000000     1.000000         1.000000
# 25%            3.000000         3.000000     3.000000         2.000000
# 50%            4.000000         3.000000     4.000000         4.000000
# 75%            5.000000         4.000000     5.000000         4.000000
# max            5.000000         5.000000     5.000000         5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count                  393.000000                       0.0
# mean                    37.885496                       NaN
# std                     66.213936                       NaN
# min                      0.000000                       NaN
# 25%                      0.000000                       NaN
# 50%                      8.000000                       NaN
# 75%                     48.000000                       NaN
# max                    530.000000                       NaN

# %%
df.describe()
# Out:
#                   id            Age  Flight Distance   Seat comfort  \
# count  129880.000000  129880.000000    129880.000000  129880.000000
# mean    64940.500000      39.427957      1981.409055       2.838597
# std     37493.270818      15.119360      1027.115606       1.392983
# min         1.000000       7.000000        50.000000       0.000000
# 25%     32470.750000      27.000000      1359.000000       2.000000
# 50%     64940.500000      40.000000      1925.000000       3.000000
# 75%     97410.250000      51.000000      2544.000000       4.000000
# max    129880.000000      85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# 50%                             3.000000        3.000000       3.000000
# 75%                             4.000000        4.000000       4.000000
# max                             5.000000        5.000000       5.000000
#
#        Inflight wifi service  Inflight entertainment  Online support  \
# count          129880.000000           129880.000000   129880.000000
# mean                3.249130                3.383477        3.519703
# std                 1.318818                1.346059        1.306511
# min                 0.000000                0.000000        0.000000
# 25%                 2.000000                2.000000        3.000000
# 50%                 3.000000                4.000000        4.000000
# 75%                 4.000000                4.000000        5.000000
# max                 5.000000                5.000000        5.000000
#
#        Ease of Online booking  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.472105          3.465075          3.485902
# std                  1.305560          1.270836          1.292226
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          3.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  5.000000          4.000000          5.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service    Cleanliness  Online boarding  \
# count     129880.000000    129880.000000  129880.000000    129880.000000
# mean           3.695673         3.340807       3.705759         3.352587
# std            1.156483         1.260582       1.151774         1.298715
# min            1.000000         0.000000       0.000000         0.000000
# 25%            3.000000         3.000000       3.000000         2.000000
# 50%            4.000000         3.000000       4.000000         4.000000
# 75%            5.000000         4.000000       5.000000         4.000000
# max            5.000000         5.000000       5.000000         5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               129880.000000             129487.000000
# mean                    14.713713                 15.091129
# std                     38.071126                 38.465650
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
# fill the NaN in Arrival Delay in Minutes with mean
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")
imputer.fit(df[['Arrival Delay in Minutes']])
# Out:
# SimpleImputer()

# %%
df[['Arrival Delay in Minutes']] = imputer.transform(df[['Arrival Delay in Minutes']])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   satisfaction_v2                    129880 non-null  object
#  2   Gender                             129880 non-null  object
#  3   Customer Type                      129880 non-null  object
#  4   Age                                129880 non-null  int64
#  5   Type of Travel                     129880 non-null  object
#  6   Class                              129880 non-null  object
#  7   Flight Distance                    129880 non-null  int64
#  8   Seat comfort                       129880 non-null  int64
#  9   Departure/Arrival time convenient  129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
#  11  Gate location                      129880 non-null  int64
#  12  Inflight wifi service              129880 non-null  int64
#  13  Inflight entertainment             129880 non-null  int64
#  14  Online support                     129880 non-null  int64
#  15  Ease of Online booking             129880 non-null  int64
#  16  On-board service                   129880 non-null  int64
#  17  Leg room service                   129880 non-null  int64
#  18  Baggage handling                   129880 non-null  int64
#  19  Checkin service                    129880 non-null  int64
#  20  Cleanliness                        129880 non-null  int64
#  21  Online boarding                    129880 non-null  int64
#  22  Departure Delay in Minutes         129880 non-null  int64
#  23  Arrival Delay in Minutes           129880 non-null  float64
# dtypes: float64(1), int64(18), object(5)
# memory usage: 23.8+ MB

# %%
obj_col = df.select_dtypes('object').columns

# %%
# data preprocessing: Label Encoding
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

for i in obj_col:
  df[i]= le.fit_transform(df[i]) 

df.head()
# Out:
#        id  satisfaction_v2  Gender  Customer Type  Age  Type of Travel  Class  \
# 0   11112                1       0              0   65               1      1
# 1  110278                1       1              0   47               1      0
# 2  103199                1       0              0   15               1      1
# 3   47462                1       0              0   60               1      1
# 4  120011                1       0              0   70               1      1
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  ...  \
# 0              265             0                                  0  ...
# 1             2464             0                                  0  ...
# 2             2138             0                                  0  ...
# 3              623             0                                  0  ...
# 4              354             0                                  0  ...
#
#    Online support  Ease of Online booking  On-board service  Leg room service  \
# 0               2                       3                 3                 0
# 1               2                       3                 4                 4
# 2               2                       2                 3                 3
# 3               3                       1                 1                 0
# 4               4                       2                 2                 0
#
#    Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                 3                5            3                2
# 1                 4                2            3                2
# 2                 4                4            4                2
# 3                 1                4            1                3
# 4                 2                4            2                5
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                           0                       0.0
# 1                         310                     305.0
# 2                           0                       0.0
# 3                           0                       0.0
# 4                           0                       0.0
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#                   id  satisfaction_v2         Gender  Customer Type  \
# count  129880.000000    129880.000000  129880.000000  129880.000000
# mean    64940.500000         0.547328       0.492616       0.183092
# std     37493.270818         0.497757       0.499947       0.386743
# min         1.000000         0.000000       0.000000       0.000000
# 25%     32470.750000         0.000000       0.000000       0.000000
# 50%     64940.500000         1.000000       0.000000       0.000000
# 75%     97410.250000         1.000000       1.000000       0.000000
# max    129880.000000         1.000000       1.000000       1.000000
#
#                  Age  Type of Travel          Class  Flight Distance  \
# count  129880.000000   129880.000000  129880.000000    129880.000000
# mean       39.427957        0.309416       0.593864      1981.409055
# std        15.119360        0.462255       0.621378      1027.115606
# min         7.000000        0.000000       0.000000        50.000000
# 25%        27.000000        0.000000       0.000000      1359.000000
# 50%        40.000000        0.000000       1.000000      1925.000000
# 75%        51.000000        1.000000       1.000000      2544.000000
# max        85.000000        1.000000       2.000000      6951.000000
#
#         Seat comfort  Departure/Arrival time convenient  ...  Online support  \
# count  129880.000000                      129880.000000  ...   129880.000000
# mean        2.838597                           2.990645  ...        3.519703
# std         1.392983                           1.527224  ...        1.306511
# min         0.000000                           0.000000  ...        0.000000
# 25%         2.000000                           2.000000  ...        3.000000
# 50%         3.000000                           3.000000  ...        4.000000
# 75%         4.000000                           4.000000  ...        5.000000
# max         5.000000                           5.000000  ...        5.000000
#
#        Ease of Online booking  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.472105          3.465075          3.485902
# std                  1.305560          1.270836          1.292226
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          3.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  5.000000          4.000000          5.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service    Cleanliness  Online boarding  \
# count     129880.000000    129880.000000  129880.000000    129880.000000
# mean           3.695673         3.340807       3.705759         3.352587
# std            1.156483         1.260582       1.151774         1.298715
# min            1.000000         0.000000       0.000000         0.000000
# 25%            3.000000         3.000000       3.000000         2.000000
# 50%            4.000000         3.000000       4.000000         4.000000
# 75%            5.000000         4.000000       5.000000         4.000000
# max            5.000000         5.000000       5.000000         5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               129880.000000             129880.000000
# mean                    14.713713                 15.091129
# std                     38.071126                 38.407410
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000
#
# [8 rows x 24 columns]

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=False,linewidths=0.5)

# %%
# start feature scaling
# split df into X and y
X=df.iloc[:,2:].values
y=df.satisfaction_v2.values

# %%
X
# Out:
# array([[  0.,   0.,  65., ...,   2.,   0.,   0.],
#        [  1.,   0.,  47., ...,   2., 310., 305.],
#        [  0.,   0.,  15., ...,   2.,   0.,   0.],
#        ...,
#        [  1.,   1.,  69., ...,   2., 155., 163.],
#        [  1.,   1.,  66., ...,   2., 193., 205.],
#        [  0.,   1.,  38., ...,   3., 185., 186.]])

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
#Splitting the data into training & test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
#Feature Scaling
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

#fit_transform for training, and transform for test --> We fit the training data for model building

# %%
X_train
# Out:
# array([[0.        , 0.        , 0.25641026, ..., 0.6       , 0.06206897,
#         0.0484375 ],
#        [0.        , 0.        , 0.58974359, ..., 0.8       , 0.00306513,
#         0.003125  ],
#        [1.        , 0.        , 0.14102564, ..., 0.6       , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.38461538, ..., 0.8       , 0.03448276,
#         0.034375  ],
#        [1.        , 0.        , 0.19230769, ..., 0.8       , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.37179487, ..., 0.8       , 0.0183908 ,
#         0.        ]])

# %%
X_test
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 7.17948718e-01, ...,
#         6.00000000e-01, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 4.48717949e-01, ...,
#         8.00000000e-01, 5.36398467e-03, 2.34375000e-03],
#        [0.00000000e+00, 0.00000000e+00, 6.02564103e-01, ...,
#         2.00000000e-01, 5.36398467e-03, 7.81250000e-04],
#        ...,
#        [0.00000000e+00, 1.00000000e+00, 4.10256410e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 3.51562500e-02],
#        [0.00000000e+00, 0.00000000e+00, 3.58974359e-01, ...,
#         1.00000000e+00, 2.29885057e-03, 8.59375000e-03],
#        [1.00000000e+00, 0.00000000e+00, 1.92307692e-01, ...,
#         4.00000000e-01, 0.00000000e+00, 0.00000000e+00]])

# %%
# start trying different classifier models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
model_kNN = KNeighborsClassifier()
model_dt = DecisionTreeClassifier(criterion='entropy')
model_rf = RandomForestClassifier(n_estimators=200)
model_nb = GaussianNB()
model_sv = SVC()
model_lr = LogisticRegression()

model_list = [model_kNN,model_dt,model_rf,model_nb,model_sv,model_lr]

# %%
for model in model_list:
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  result = accuracy_score(y_test, y_pred)
  print(model,'\n','Accuracy is: ', result*100,'\n')
  print(classification_report(y_test, y_pred))
# test size: 0.25
# Out:
# KNeighborsClassifier()
#  Accuracy is:  92.68247613181398
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     14688
#            1       0.95      0.92      0.93     17782
#
#     accuracy                           0.93     32470
#    macro avg       0.93      0.93      0.93     32470
# weighted avg       0.93      0.93      0.93     32470
#
# DecisionTreeClassifier(criterion='entropy')
#  Accuracy is:  93.96673852787188
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     14688
#            1       0.94      0.95      0.94     17782
#
#     accuracy                           0.94     32470
#    macro avg       0.94      0.94      0.94     32470
# weighted avg       0.94      0.94      0.94     32470
#
# RandomForestClassifier(n_estimators=200)
#  Accuracy is:  95.8484755158608
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     14688
#            1       0.97      0.95      0.96     17782
#
#     accuracy                           0.96     32470
#    macro avg       0.96      0.96      0.96     32470
# weighted avg       0.96      0.96      0.96     32470
#
# GaussianNB()
#  Accuracy is:  81.71850939328611
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80     14688
#            1       0.83      0.84      0.83     17782
#
#     accuracy                           0.82     32470
#    macro avg       0.82      0.82      0.82     32470
# weighted avg       0.82      0.82      0.82     32470
#
# SVC()
#  Accuracy is:  94.15768401601478
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     14688
#            1       0.94      0.95      0.95     17782
#
#     accuracy                           0.94     32470
#    macro avg       0.94      0.94      0.94     32470
# weighted avg       0.94      0.94      0.94     32470
#
# LogisticRegression()
#  Accuracy is:  83.47397597782569
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     14688
#            1       0.85      0.85      0.85     17782
#
#     accuracy                           0.83     32470
#    macro avg       0.83      0.83      0.83     32470
# weighted avg       0.83      0.83      0.83     32470

# %%
#Applying PCA
from sklearn.decomposition import PCA

# %%
com_list = list(range(5,22,5))
result_list = []

for n_com in com_list:
  pca = PCA(n_components = n_com)
  X_train_pca = pca.fit_transform(X_train)
  X_test_pca = pca.transform(X_test)
  for model in model_list:
    model.fit(X_train_pca, y_train)
    y_pred = model.predict(X_test_pca)
    result = accuracy_score(y_test, y_pred)
    r = []
    r.append(n_com)
    r.append(model)
    r.append(result*100)
    result_list.append(r)

result_list
# Out:
# [[5, KNeighborsClassifier(), 90.12319063751156],
#  [5, DecisionTreeClassifier(criterion='entropy'), 87.40067754850631],
#  [5, RandomForestClassifier(n_estimators=200), 90.85617493070527],
#  [5, GaussianNB(), 80.61287342161995],
#  [5, SVC(), 88.8019710502002],
#  [5, LogisticRegression(), 79.06067138897444],
#  [10, KNeighborsClassifier(), 91.4197720973206],
#  [10, DecisionTreeClassifier(criterion='entropy'), 88.64490298737296],
#  [10, RandomForestClassifier(n_estimators=200), 92.12503849707421],
#  [10, GaussianNB(), 81.84170003079765],
#  [10, SVC(), 91.77702494610409],
#  [10, LogisticRegression(), 82.6208808130582],
#  [15, KNeighborsClassifier(), 92.04496458269172],
#  [15, DecisionTreeClassifier(criterion='entropy'), 89.19310132429935],
#  [15, RandomForestClassifier(n_estimators=200), 92.79642747151216],
#  [15, GaussianNB(), 80.57899599630429],
#  [15, SVC(), 93.63104404065291],
#  [15, LogisticRegression(), 82.99661225746843],
#  [20, KNeighborsClassifier(), 92.63319987680936],
#  [20, DecisionTreeClassifier(criterion='entropy'), 89.95072374499537],
#  [20, RandomForestClassifier(n_estimators=200), 93.44933785032337],
#  [20, GaussianNB(), 80.3541730828457],
#  [20, SVC(), 94.66584539574993],
#  [20, LogisticRegression(), 83.54173082845703]]

# %%
# find out RandomForest generates the best accuracy, while PCA does not help saving a significant amount of time

# %%
df.satisfaction_v2.value_counts() # the targeted col. contains inbalance results
# Out:
# 1    71087
# 0    58793
# Name: satisfaction_v2, dtype: int64

# %%
# so start resampling with SMOTEENN

from imblearn.combine import SMOTEENN
sm = SMOTEENN()
X_train_sen, y_train_sen = sm.fit_resample(X_train, y_train)

model_rf.fit(X_train_sen, y_train_sen)
y_pred_sen = model_rf.predict(X_test)

result_sen = accuracy_score(y_test, y_pred_sen)
print(model_rf,'\n','Accuracy is: ', result_sen*100,'\n')
print(confusion_matrix(y_test, y_pred_sen))
# Out:
# RandomForestClassifier(n_estimators=200)
#  Accuracy is:  94.62580843855866
#
# [[14077   576]
#  [ 1169 16648]]

# %%
print(classification_report(y_test, y_pred_sen))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     14653
#            1       0.97      0.93      0.95     17817
#
#     accuracy                           0.95     32470
#    macro avg       0.94      0.95      0.95     32470
# weighted avg       0.95      0.95      0.95     32470

# %%
# start trying ensemble learning

from sklearn import model_selection
from sklearn.ensemble import VotingClassifier

# %%
model_list
# Out:
# [KNeighborsClassifier(),
#  DecisionTreeClassifier(criterion='entropy'),
#  RandomForestClassifier(n_estimators=200),
#  GaussianNB(),
#  SVC(),
#  LogisticRegression()]

# %%
X_test
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 7.17948718e-01, ...,
#         6.00000000e-01, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 4.48717949e-01, ...,
#         8.00000000e-01, 5.36398467e-03, 2.34375000e-03],
#        [0.00000000e+00, 0.00000000e+00, 6.02564103e-01, ...,
#         2.00000000e-01, 5.36398467e-03, 7.81250000e-04],
#        ...,
#        [0.00000000e+00, 1.00000000e+00, 4.10256410e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 3.51562500e-02],
#        [0.00000000e+00, 0.00000000e+00, 3.58974359e-01, ...,
#         1.00000000e+00, 2.29885057e-03, 8.59375000e-03],
#        [1.00000000e+00, 0.00000000e+00, 1.92307692e-01, ...,
#         4.00000000e-01, 0.00000000e+00, 0.00000000e+00]])

# %%
y_test
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
# plot ROC curve
from sklearn import metrics

ax = plt.gca()
for i in model_list:
  metrics.plot_roc_curve(i, X_test, y_test, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
ax = plt.gca()
for i in model_list:
  metrics.plot_confusion_matrix(i, X_test, y_test, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
